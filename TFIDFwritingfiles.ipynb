# %% [markdown]
# #TF-IDF

# %%
#%%writefile modeling_tfidf.py

# Imports
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from joblib import dump

# Load the data, as packages
packages = pd.read_csv("./data/packages_11_may_2022.csv")
# There are 18550 packages 

# Create the TF-IDF model, called vectors
vectorizer = TfidfVectorizer(lowercase=True, strip_accents='unicode', stop_words='english')
vectors = vectorizer.fit_transform(packages['Description'])

# Joblib dump model, saved as `tf-idf.joblib`
dump(vectors, 'tf-idf.joblib')
# Out:
# ['tf-idf.joblib']

# %%
packages.tail().to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Unnamed: 0</th>\n      <th>Package</th>\n      <th>Version</th>\n      <th>Priority</th>\n      <th>Depends</th>\n      <th>Imports</th>\n      <th>LinkingTo</th>\n      <th>Suggests</th>\n      <th>Enhances</th>\n      <th>License</th>\n      <th>License_is_FOSS</th>\n      <th>License_restricts_use</th>\n      <th>OS_type</th>\n      <th>Archs</th>\n      <th>MD5sum</th>\n      <th>NeedsCompilation</th>\n      <th>File</th>\n      <th>Repository</th>\n      <th>Title</th>\n      <th>Description</th>\n      <th>page.rank</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>18545</th>\n      <td>18546</td>\n      <td>zTree</td>\n      <td>1.0.7</td>\n      <td>NaN</td>\n      <td>R (&gt;= 3.1.0)</td>\n      <td>plyr (&gt;= 1.0)</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>GPL-3 | file LICENSE</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>ef7ec3d28753f147de892d0b38d5db3e</td>\n      <td>no</td>\n      <td>NaN</td>\n      <td>http://mran.revolutionanalytics.com/snapshot/2022-05-10/src/contrib</td>\n      <td>Functions to Import Data from \'z-Tree\' into R</td>\n      <td>Read \'.xls\' and \'.sbj\' files which are written by the\\n   Microsoft Windows program \'z-Tree\'. The latter is a software for\\n   developing and carrying out economic experiments\\n   (see &lt;http://www.ztree.uzh.ch/&gt; for more information).</td>\n      <td>0.000014</td>\n    </tr>\n    <tr>\n      <th>18546</th>\n      <td>18547</td>\n      <td>ztype</td>\n      <td>0.1.0</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>magrittr, rvest, stats, stringr, utils, dplyr, ggplot2,\\nlubridate, assertthat</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>GPL-3</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>28d75de6acc106becb6e49fe6a0d7ed7</td>\n      <td>no</td>\n      <td>NaN</td>\n      <td>http://mran.revolutionanalytics.com/snapshot/2022-05-10/src/contrib</td>\n      <td>Run a Ztype Game Loaded with R Functions</td>\n      <td>How fast can you type R functions on your keyboard? Find out by running a \'zty.pe\' game: export R functions as instructions to type to destroy opponents vessels.</td>\n      <td>0.000038</td>\n    </tr>\n    <tr>\n      <th>18547</th>\n      <td>18548</td>\n      <td>ZVCV</td>\n      <td>2.1.1</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>Rcpp (&gt;= 0.11.0), glmnet, abind, mvtnorm, stats, Rlinsolve,\\nmagrittr, dplyr</td>\n      <td>Rcpp, RcppArmadillo, BH</td>\n      <td>partitions, ggplot2, ggthemes</td>\n      <td>NaN</td>\n      <td>GPL (&gt;= 2)</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>8a9bebfc5fb53f1e7050c410becc9776</td>\n      <td>yes</td>\n      <td>NaN</td>\n      <td>http://mran.revolutionanalytics.com/snapshot/2022-05-10/src/contrib</td>\n      <td>Zero-Variance Control Variates</td>\n      <td>Stein control variates can be used to improve Monte Carlo estimates of expectations when the derivatives of the log target are available. This package implements a variety of such methods, including zero-variance control variates (ZV-CV, Mira et al. (2013) &lt;doi:10.1007/s11222-012-9344-6&gt;), regularised ZV-CV (South et al., 2018 &lt;arXiv:1811.05073&gt;), control functionals (CF, Oates et al. (2017) &lt;doi:10.1111/rssb.12185&gt;) and semi-exact control functionals (SECF, South et al., 2020 &lt;arXiv:2002.00033&gt;). ZV-CV is a parametric approach that is exact for (low order) polynomial integrands with Gaussian targets. CF is a non-parametric alternative that offers better than the standard Monte Carlo convergence rates. SECF has both a parametric and a non-parametric component and it offers the advantages of both for an additional computational cost. Functions for applying ZV-CV a ...

# %%
#%%writefile results.py

# Imports
import pandas as pd
import numpy as np
from joblib import load

# Load the model 
vectors = load('tf-idf.joblib') 

def get_closest(query, w = 0.5, sort_by = "PageRank"):
    result = vectorizer.fit(packages['Description']).transform([query]) # Matrix of 1x 55750
    pairwise_similarity = result * vectors.T

    indexes = (-pairwise_similarity.toarray()[0]).argsort()[:20]
    
    df = [packages["Package"], 
      packages["Version"], 
      packages["Title"], 
      packages["Description"], 
      packages["page.rank"],
      pd.Series(pairwise_similarity.toarray()[0])]

    headers = ["Package_name", "Version", "Title", "Description", "PageRank", "PW_Similarity"]

    df = pd.concat(df, axis=1, keys=headers)
    df["Mix"] = df["PageRank"]*df["PW_Similarity"]
    #df["Mix"] = w*df["PageRank"] + (1-w)*df["PW_Similarity"]
    df = df.iloc[indexes].sort_values(by = [sort_by], ascending=False)
    return df

# %%
#%%writefile testing.py
#from results import get_closest
# the sum would require standardizing both columns, instead we multiply
get_closest("map visualization graph network", sort_by = "Mix")
# Out:
#              Package_name     Version  \
# 7347               igraph       1.3.1
# 15721                 sna         2.6
# 10475             network      1.17.1
# 16104           spNetwork     0.4.3.1
# 8933             mapStats         2.4
# 15805              SOMEnv       1.1.2
# 15399             sigmajs       0.1.5
# 10487    networkreporting       0.1.1
# 1255               bingat         1.3
# 10455              netmap       0.1.1
# 10453             netjack       1.2.0
# 16102               spnet     0.9.1-0
# 17160               tiler       0.2.5
# 8317   leaflet.minicharts       0.6.2
# 10460             netplot       0.1-1
# 15486       simplegraphdb  2021.03.10
# 5940           geomapdata       2.0-0
# 9044          maxmatching       0.1.0
# 13010          rasterList       0.5.8
# 5148                 FGSG       1.0.2
#
#                                                    Title  \
# 7347                  Network Analysis and Visualization
# 15721                  Tools for Social Network Analysis
# 10475                        Classes for Relational Data
# 16104                        Spatial Analysis on Network
# 8933        Geographic Display of Survey Data Statistics
# 15805  SOM Algorithm for the Analysis of Multivariate...
# 15399  Interface to 'Sigma.js' Graph Visualization Li...
# 10487       Tools for using Network Reporting Estimators
# 1255                         Binary Graph Analysis Tools
# 10455                 Represent Network Objects on a Map
# 10453         Tools for Working with Samples of Networks
# 16102                 Plotting (Social) Networks on Maps
# 17160     Create Geographic and Non-Geographic Map Tiles
# 8317                    Mini Charts for Interactive Maps
# 10460                            Beautiful Graph Drawing
# 15486                            A Simple Graph Database
# 5940           Data for Topographic and Geologic Mapping
# 9044         Maximum Matching for General Weighted Graph
# 13010           A Raster Where Cells are Generic Objects
# 5148   Feature Grouping and Selection Over an Undirec...
#
#                                              Description  PageRank  \
# 7347   Routines for simple graphs and network analysi...  0.003454
# 15721  A range of tools for social network analysis, ...  0.000294
# 10475  Tools to create and modify network objects.  T...  0.000416
# 16104  Perform spatial analysis on network.\n    Impl...  0.000093
# 8933   Automated calculation and visualization of sur...  0.000051
# 15805  Analysis of multivariate environmental high fr...  0.000048
# 15399  Interface to 'sigma.js' graph visualization li...  0.000052
# 10487  Functions useful\n    for producing estimates ...  0.000045
# 1255              Tools to analyze binary graph objects.  0.000038
# 10455  Represent 'network' or 'igraph' objects whose ...  0.000037
# 10453  Tools for managing large sets of network data ...  0.000029
# 16102  Facilitates the rendering of networks for whic...  0.000019
# 17160  Creates geographic map tiles from geospatial m...  0.000027
# 8317   Add and modify small charts on an interactive ...  0.000027
# 10460  A graph visualization engine that puts an emph...  0.000024
# 15486  This is a graph database in 'SQLite'.  It is i...  0.000023
# 5940   Data sets included here are for use with packa...  0.000014
# 9044   Computes the maximum matching for unweighted g...  0.000014
# 13010  A S4 class has been created such that complex ...  0.000013
# 5148   Implement algorithms for feature grouping and ...  0.000009
#
#        PW_Similarity       Mix
# 7347        0.292460  0.001010
# 15721       0.477737  0.000140
# 10475       0.296832  0.000124
# 16104       0.286631  0.000027
# 8933        0.321006  0.000016
# 15805       0.271464  0.000013
# 15399       0.243395  0.000013
# 10487       0.235585  0.000011
# 1255        0.269041  0.000010
# 10455       0.255960  0.000009
# 10453       0.306078  0.000009
# 16102       0.421513  0.000008
# 17160       0.240071  0.000006
# 8317        0.234936  0.000006
# 10460       0.249352  0.000006
# 15486       0.247772  0.000006
# 5940        0.379643  0.000005
# 9044        0.242593  0.000003
# 13010       0.249379  0.000003
# 5148        0.309636  0.000003

# %%
a = "a"

# %%
a == ""
# Out:
# False

# %% [markdown]
# # Word2Vec
